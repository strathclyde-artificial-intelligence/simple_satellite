# %%
import os
os.environ['PYGAME_HIDE_SUPPORT_PROMPT'] = '1'
import pygame

from agent.AgentGreedy import GreedyAgent
from agent.AgentPDDL import PDDLAgent
from simulation.DrawSim import SatelliteView
from simulation.Simulation import SatelliteSim

if __name__ == '__main__':

    pygame.display.init()
    finished = False
    clock = pygame.time.Clock()

    # create simulation
    sim = SatelliteSim()
    print(sim.PERIOD)
    sim.initRandomStations(2)
    sim.initRandomTargets(10)
    sim.goalRef.generateSingleGoals(sim.targets, 5)
    sim.goalRef.generateCampaigns(sim.targets, sim.goalRef.MAX_CAMPAIGNS)
    view = SatelliteView(sim)

    # create agent
    agent = PDDLAgent()
    #agent = GreedyAgent()

    while not finished:

        # check for window closed
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                finished = True

        view.drawSim(sim)
        action = agent.getAction(sim)
        finished = finished or sim.update(action, 0.5)
        clock.tick(60)

    pygame.quit()
# Out:
# 600
# (PDDLAgent) generating a plan
# (PDDLAgent) planning complete
# (PDDLAgent) plan will start on orbit 1 at time 600
# (0, 4, 0)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 4, 0)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (0, 6, 1)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 6, 1)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (0, 9, 2)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 9, 2)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (1, 9, 2)
# WARN: action could not be accomplished as ground station out of range (dump)
# (1, 6, 1)
# WARN: action could not be accomplished as memory does not hold required image (dump)
# (0, 5, 1)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 5, 1)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (1, 5, 1)
# WARN: action could not be accomplished as ground station out of range (dump)
# (1, 4, 0)
# WARN: action could not be accomplished as memory does not hold required image (dump)
# (0, 8, 0)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 8, 0)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (1, 8, 0)
# (PDDLAgent) plan complete
# WARN: action could not be accomplished as ground station out of range (dump)
# (PDDLAgent) generating a plan
# (PDDLAgent) planning complete
# (PDDLAgent) plan will start on orbit 5 at time 3000
# (0, 1, 0)
# (2, 1, 0)
# (1, 1, 0)
# (0, 6, 0)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 6, 0)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (0, 9, 1)
# WARN: action could not be accomplished as target out of range (take_image)
# (0, 5, 2)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 5, 2)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (2, 9, 1)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (0, 3, 3)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 3, 3)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (0, 7, 4)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 7, 4)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (1, 7, 4)
# WARN: action could not be accomplished as memory does not hold required image (dump)
# (0, 8, 4)
# WARN: action could not be accomplished as target out of range (take_image)
# (0, 0, 5)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 0, 5)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (2, 8, 4)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (0, 4, 6)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 4, 6)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (1, 4, 6)
# WARN: action could not be accomplished as ground station out of range (dump)
# (1, 0, 5)
# WARN: action could not be accomplished as memory does not hold required image (dump)
# (1, 8, 4)
# WARN: action could not be accomplished as ground station out of range (dump)
# (1, 3, 3)
# WARN: action could not be accomplished as memory does not hold required image (dump)
# (1, 5, 2)
# WARN: action could not be accomplished as ground station out of range (dump)
# (1, 9, 1)
# WARN: action could not be accomplished as memory does not hold required image (dump)
# (1, 6, 0)
# (PDDLAgent) plan complete
# WARN: action could not be accomplished as ground station out of range (dump)
# (PDDLAgent) generating a plan
# (PDDLAgent) planning complete
# (PDDLAgent) plan will start on orbit 12 at time 7200
# (0, 2, 0)
# (2, 2, 0)
# (1, 2, 0)
# (0, 6, 0)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 6, 0)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (0, 9, 1)
# WARN: action could not be accomplished as target out of range (take_image)
# (0, 5, 2)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 5, 2)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (2, 9, 1)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (0, 3, 3)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 3, 3)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (0, 7, 4)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 7, 4)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (1, 7, 4)
# WARN: action could not be accomplished as memory does not hold required image (dump)
# (0, 8, 4)
# WARN: action could not be accomplished as target out of range (take_image)
# (0, 0, 5)
# WARN: action could not be accomplished as target out of range (take_image)
# (2, 0, 5)
# WARN: action could not be accomplished as memory does not hold required image (analyse)
# (2, 8, 4)
# WARN: action could not be accomplished as memory does not hold required image (analyse)

# %%
pygame.quit()
